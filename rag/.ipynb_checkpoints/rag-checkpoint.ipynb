# %%
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

# %%
import os
from dotenv import load_dotenv
load_dotenv("../.env")

smith_key = os.getenv("LANG_SMITH_API_KEY")

# %%
# setup vector database
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2",
                                  model_kwargs={"device": "cpu"})
vectore_store = Chroma(
    collection_name="cs50_policy",
    embedding_function=embeddings,
    persist_directory="./chroma_db"
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
# read txt file
with open("policy.txt",'r',encoding="utf-8") as file:
    text = file.read()

# chunk text
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 300,
    chunk_overlap = 100,
    separators=[" ", ""]
)

chunks = text_splitter.split_text(text)

# convert chunks to Documents
documents = [Document(page_content=chunk) for chunk in chunks]

# %%
# store documents in chromaDB
vectore_store.add_documents(documents=documents)
# Out:
# ['eb356b57-0b54-42de-a151-e9d245ed2822',
#  '65adf081-d0b2-4b5e-9047-2969e7630cec',
#  'a51eae69-67f1-4567-9cbe-263d7d6c6ee7',
#  '82f896a5-2c13-4aec-a0b4-a3e836290b7c',
#  'e5413981-61cf-4b2d-babe-3654a364e3bf',
#  '2b60310b-7ef9-4bf9-a1e1-10b47ca0a058',
#  'f1f9cfc8-19b2-4957-9c1c-25bcce2585cd',
#  '9fa84ec5-6f57-45cc-8726-8ecc0a0e361f',
#  '32c5190b-9e7f-4c2a-986b-f07b006de44c',
#  '6f197281-a4d0-4a47-a509-14ffcd8bff42',
#  '08c9f11f-b079-4a81-b97c-a4de1997ecbe',
#  'a64565a1-ad84-449e-9cfc-c8238302fbc9',
#  '5a7bed00-2ddc-495c-8bef-57cf20e2bea0',
#  '75a29cfe-d01c-44c1-817a-372220456725',
#  '5512d681-efc7-4489-8c6c-03ec584cd180',
#  '084b8044-6817-4a7b-a56f-0e7249cd5fba',
#  '8cf45f1d-a8b7-4cd4-9aff-851f92f0c844',
#  '2f16ca19-93c4-4cad-a6cf-e6d8a709d1ae',
#  '94e289e1-7d54-4773-bc1b-937bf19f54bb',
#  '3cd7ce7d-044d-4f54-9e9f-768c0873f5ee',
#  '787d4d33-4a2b-4118-8355-6da0943d491c',
#  '2fef5277-4b93-4974-8815-7e875bfde268',
#  'c7017964-c712-43dc-8366-9e909ed3a53c',
#  '4ee08f2a-3ac4-4cf9-97f5-83c84eb3138b',
#  '8e7509b2-7e65-4a73-97da-e4a84564aade',
#  'b04b5096-788e-48ca-8e18-b0ef93c70f89',
#  '81fbb504-78e0-4e55-ac6e-e41fbb1da346',
#  '8b1934c9-3110-41d5-8d76-ee8f4d58e2b7',
#  '3dd99c84-06fe-44b5-82e6-14eb01fabdcf',
#  '729ff4cf-afe8-448e-9e08-6bb6c1976203',
#  '8026cd5d-eb07-46d5-83d3-a6ce4d7e722a',
#  '7e09a76b-2cff-405c-9fdb-84c6ccedfd14',
#  '6a225774-edcc-4a6b-b14c-c9fa8dc8ece5',
#  '18178a0d-0499-4d9c-8186-149cfb5b525a',
#  '6ad8b385-693d-4434-81f1-4acec4f27373',
#  'd163ad7f-5d0f-4e40-bcf5-ecccc67f81a3',
#  'e2efd70a-d826-4d93-a9dd-a1e0af642558',
#  '3f3c847d-af96-45bf-92f2-6e3acc3397e1',
#  '8dc2826d-1e60-47ef-9f14-4d29819ed9ab',
#  '57820963-3b15-4ecc-8646-f819f77b664a',
#  '40ec0aad-60d9-4a22-b706-08f50b50d9e0',
#  '72946973-2815-4c53-b87f-6320f1e9d5db',
#  '14308200-87ed-4e50-8cca-fd44acc9849c',
#  '23942f11-5435-47fa-b088-4d3c50428b86',
#  '81ecd367-8c6c-47a1-b073-f7e74beebb93',
#  'f71e2487-e80d-4b81-a9b7-76eda7aab17f',
#  'a9e441aa-5477-48a0-9040-2e3ac006c9ae',
#  '34c04d1d-54a5-40ea-90c7-f64f23d20823',
#  '9c4191ad-4ead-4293-8a0e-55b7f9f82a5d',
#  '02d7a771-85d8-43db-a3cd-fb2c284e46f0',
#  '01cc21de-3c9c-4531-b29d-4f8ff7081c19',
#  'ce25b9f7-3c72-47c5-ad13-aa4ff91ab8d0',
#  'bda4d6eb-8f27-48e8-889e-c4553326c0e5',
#  'd2c4e4f9-790d-44ce-9e8c-3c4dc8500508',
#  '37f30bb3-c5d6-49fe-95fa-f825b979a32e',
#  '47e603c3-a2b8-48b8-a6be-72a45ed3869f',
#  '17739fc1-a5fe-44aa-8b07-ef743cc88ddf',
#  'd2785d0f-1072-4ac8-b84e-db7f9487197d',
#  '179777b1-d672-449a-8fd2-797cb1abe5c7',
#  '855dbf7d-d4e8-4cfb-94eb-482bee87a769',
#  '288c284e-8a92-40e0-9cfb-77ab0f3e776f',
#  'dbdfb90d-7188-40b3-a6bb-92f620fe7001',
#  '5d347616-d6e7-4f49-b2c9-e1c87224219a',
#  'ce0e6d33-b07c-428c-8a94-9c95e994f249',
#  '2e0e99e8-ca57-41e4-a8ab-3f7c93a18263',
#  '5eb9a594-7d8a-4c07-8eca-3a0a132a0492',
#  'f16f9b1f-3443-4487-95b7-c2369872ff5a',
#  '9970d49e-7356-4de2-947f-96eb64ee101b',
#  'abfe24c4-7a96-4bf9-a017-03907f9cd128',
#  '4ed0bcc3-3475-47a1-88c2-135be0e2d38e',
#  'cb2222b6-8113-4ae9-a32b-3e707d93f034',
#  'aad18187-1cd5-44fc-b5e8-a4041aefc987',
#  '98c6c8ab-48ed-404d-bcce-997e951f33de',
#  '7f0e7365-1f5e-470c-bc5a-f2052950a544',
#  'a1771594-ef43-438c-bd8a-ff68ce55f356',
#  '24814f8c-f4e0-408b-a322-3ef6e6da4633',
#  '4a0ac07d-4af6-454b-aa8d-029da3346569',
#  '48abb2ef-7970-4efd-ad35-3323b7f527d3',
#  'c165a144-c267-45e0-9507-c62d128e1994',
#  'f0e49c3e-e9f0-4a24-88ba-ac787c6b959a',
#  'e883576a-fae8-4b7f-b63f-a7a30fc1d6b0',
#  'e9a7e05c-7718-4cd9-9271-38ca19642be7',
#  '765f61ab-2d82-4584-87db-bddf12df18ff',
#  '1366ce67-5df0-4539-9677-2698ea16c7bc',
#  '95582e02-6cf6-4e4a-8c40-55de54ffe35d',
#  '99c9947b-6c14-4040-955b-a01ff422aca6',
#  '8d5f9f51-245b-4de9-94c8-cdf44f5cdcd0',
#  '56376535-2a5e-46ca-934c-dde21f7fb630',
#  'fbb60ea1-4903-4c91-9310-2b5d16e2815f',
#  '8877e81c-6115-422d-8e7f-28e9ec800621',
#  'bf3ecc47-c688-4f4d-85ec-ec03559ddf5a',
#  'c61804e7-ee5c-4280-afb2-bd2447495d11',
#  '95290bc6-d17d-4ebb-893c-cc34c0316f4b',
#  'a49bd734-31a5-4529-826d-b2442f4ce325',
#  'c8044d7c-22cc-4ac2-8726-866c9134f301',
#  'fc2651fc-8208-47da-9e76-10f94d061ca8',
#  '52351fa0-f8c7-41ad-9f7f-e2e81e522e59',
#  '0215ef03-165c-4cb9-bb66-a518591a9cd6',
#  'c90876f6-d68a-433d-9804-6dc153ab109c',
#  'e4d690d7-56b9-4002-be39-dadd9e48690e',
#  '95126ed4-86d2-4172-b5dd-b402615aa847',
#  '8b82a121-0de5-4ca6-88fc-5a8b8c4edd46',
#  '0d9de5b6-fd1d-41ac-bc09-179c468f941d',
#  'fc44a096-a438-427f-9282-6a9ad2f2664c',
#  '5e086e56-7724-4279-b790-c4b1cfcb73e4',
#  '364d4b07-523c-4dca-b927-f278c28544a7',
#  '5e659ec7-f983-4dbf-9f2d-79f4de7255c4',
#  'acfe0724-ccc9-4a8a-ad3f-b37ab5462c09',
#  '2878618b-987d-4eb0-8679-4f5c9e3f4271',
#  'ad5950c0-7617-4ec9-9796-283ed02729c6',
#  'ca90f39a-ce21-4d0b-a476-6bf7333c6a28',
#  '89434b9f-8529-4da3-b588-55dbb18c57b2',
#  '076c7522-a3dd-4209-9c40-00f49a641e09',
#  'b4434874-f471-4ed8-b600-5a5ca30b26c5',
#  '66c85f5d-aa2e-47eb-9833-19ee7d6c86e3',
#  'd93e44c7-5a6c-4f33-ace8-af13c0677a5c',
#  '2b4972e4-1ef4-4d7d-8bae-edfe7d67bdc8',
#  '1fcf31c1-9bf8-47a0-b771-0e8a5b3870e4',
#  '02d8bfef-9349-41b0-b2bd-98ac06977b78',
#  'e87467b1-f199-4148-957e-d4e5bc264ee9',
#  '741c45b6-78e9-4728-9ff2-1c32b73df5a2',
#  '074bc581-a90c-4595-b587-41275ad3f8b1',
#  '5e19fafa-07e2-44e5-ba5b-9b652cae4d82',
#  '9e64b94f-6896-455c-b64f-4248ee2eac52',
#  '4a6b3c38-3b81-441f-b9ce-112f18b03601',
#  'c72a5c27-c457-4aec-824b-1596a22311d8',
#  '377ae063-8172-49fb-a0f4-edc72ce082b5',
#  '98646947-6480-4d34-a27c-a2efadffb376',
#  'caedaf74-c154-4310-84c9-ed8bcde3e7d1',
#  '67868859-0e5d-4e35-83ab-b08ae9fdc9e2',
#  'a4c0dd0d-e458-4fb7-82ab-be0777f769de',
#  '264f6b18-6efa-4035-aa4c-5aa7b893afb3',
#  '34027e0f-e7c2-4669-b1a1-c75f72ef8c5f',
#  'ce3c9558-398a-496c-8521-7671b62715e6',
#  '1b09bc8f-c4d8-4f29-9ae3-ed44ed953965',
#  'b88dd890-e387-42d2-b081-9dfcf6a14204',
#  '0d16ddd5-fd65-461f-bf7d-5caa95beccdc',
#  '5e5894a2-83fd-4031-8192-c1b6cb7f2397',
#  '8e19124e-1a6f-485e-ae91-551d400b97bb',
#  'a27d5c36-48fc-48ff-a121-b0831196a696',
#  '3730952c-ca1c-4826-9949-3136d6666b57',
#  '743cd88d-b9eb-4dac-a82c-1d6d43397c6e',
#  '24d56dec-9fbe-4450-b30b-851bf16d0629',
#  '49bc5521-7cbe-421f-afa8-e3e7d89eb5d0',
#  '5c78b86d-d6f2-41d8-9be2-9c4a3ce12064',
#  'f376fbe8-62a8-4226-8d78-53afe64f59c5',
#  '2a8fc8a8-39ae-4a36-837a-d662d8b2b4b4',
#  '239b96cc-a98c-4c1c-ab17-e563080d4854',
#  'd05c888d-28d4-4629-9e59-8053bffa0c6e',
#  '0b10b55a-0f62-44e1-99da-9093ea5b05e1',
#  '961c547c-ee9e-4448-b19c-7abbb4891024',
#  '6df90c57-1068-4304-919b-9270400c53a3',
#  '58cb2e23-958b-4591-9338-3a38024d741b',
#  '36177427-b011-4090-9e0f-7a8b794091d2',
#  '51055969-8254-4631-bcd5-6fb8701ab5a4',
#  'b59f4a38-20dc-4c91-af9c-fdb6bcb16b46',
#  '24c05b3f-f17c-4f49-908a-81b167a71eb0',
#  '143bc4f4-68db-45a2-80f2-0656cde3da2f',
#  '3fa69f90-11e1-4e9c-8f71-7745b513cbae',
#  '0e9377e7-1a34-4ac6-a4a2-6a0290226bc6',
#  '2bacbfed-a80f-4ec0-b1d9-02af202ac67b',
#  '72d817aa-4dd7-4198-873c-aca121bdb0bf',
#  '659f12f8-17af-43af-8880-c941decb10b7',
#  '34cc689c-f1dd-4c36-97a2-ebe5565c5b84']

# %%
# similarity search
results = vectore_store.similarity_search("can i take this course?",k=2)
results
# Out:
# [Document(id='82f896a5-2c13-4aec-a0b4-a3e836290b7c', metadata={}, page_content='examine our course map to determine if this class is the right one for you at this point in your development as a learner.\n\nCan this course be used to fulfill official academic requirements for my university, college, or school?\nOur free and verified certificates are not accredited academic'),
#  Document(id='a51eae69-67f1-4567-9cbe-263d7d6c6ee7', metadata={}, page_content='in signing up for these free services.\n\nDoes this course have prerequisites?\nWhile you are not required to take or show proof that you have passed a previous course, it is highly recommended that you examine our course map to determine if this class is the right one for you at this point in your')]

# %%
vectore_store.delete_collection()

# %%
len(vectore_store.get()["ids"])
# Out:
# 164

# %%
chunks
# Out:
# ['Should I Take This Course?\nAm I or my child too young to take this course?\nOur courses are perhaps best suited for learners ages 12 and up. Younger learners might need a hand from a parent. Please note that your local laws and policies may prevent learners under certain ages from utilizing free',
#  'note that your local laws and policies may prevent learners under certain ages from utilizing free third-party services associated with this course. Accordingly, younger learners may need your assistance in signing up for these free services.\n\nDoes this course have prerequisites?\nWhile you are not',
#  'in signing up for these free services.\n\nDoes this course have prerequisites?\nWhile you are not required to take or show proof that you have passed a previous course, it is highly recommended that you examine our course map to determine if this class is the right one for you at this point in your',
#  'examine our course map to determine if this class is the right one for you at this point in your development as a learner.\n\nCan this course be used to fulfill official academic requirements for my university, college, or school?\nOur free and verified certificates are not accredited academic',
#  'my university, college, or school?\nOur free and verified certificates are not accredited academic offerings from Harvard or any of its affiliate institutions. We offer these certificates for self-educational and vocational purposes.\n\nSchools and universities throughout the world have varying rules',
#  'and vocational purposes.\n\nSchools and universities throughout the world have varying rules about what specifically they will accept for academic transfer credit. Accordingly, you should speak to your specific academic advisors about your individual situation. It’s possible (though you will have to',
#  'specific academic advisors about your individual situation. It’s possible (though you will have to verify with your advisors) that our certificate will satisfy their requirements. Indeed, some of our courses (facilitated through edX) are recommended by the American Council on Education (ACE) for',
#  'courses (facilitated through edX) are recommended by the American Council on Education (ACE) for college or university credit, which your own academic institution may honor.\n\nIf you are looking for an accredited academic course or certificate at the undergraduate or graduate level, consider',
#  'for an accredited academic course or certificate at the undergraduate or graduate level, consider exploring Harvard Extension.\n\nIf you are a high school student looking for academic credit, best to show your teacher or academic counselor CS50 AP. You will need to obtain their authorization to gain',
#  'your teacher or academic counselor CS50 AP. You will need to obtain their authorization to gain official academic credit. You are very welcome to take this or any of our courses. However, only your official school representatives can provide you with academic credit for completing any of our',
#  'your official school representatives can provide you with academic credit for completing any of our courses.\n\nHow can I take advantage of American Council on Education (ACE) credit recommendation?\nACE, in the words of their own website, helps learners seeking “to jump-start [their] college careers',
#  'in the words of their own website, helps learners seeking “to jump-start [their] college careers with transfer credit, or open up new employment opportunities with badges.” Further, they state “the ACE National Guide [can be used] to find courses and exams that carry college credit or competency',
#  'ACE National Guide [can be used] to find courses and exams that carry college credit or competency recommendations.”\n\nSome of our courses, facilitated through edX’s verified certificate program, are included in the ACE National Guide. As of the last revision of these FAQs, our courses that appear',
#  'included in the ACE National Guide. As of the last revision of these FAQs, our courses that appear in the ACE National Guide include:\n\nCS50x: Introduction to Computer Science;\nCS50 AI: Introduction to Artificial Intelligence with Python; and\nCS50 Web: Web Programming with Python and',
#  'Introduction to Artificial Intelligence with Python; and\nCS50 Web: Web Programming with Python and JavaScript.\nYour college or university, present or future, may accept our courses that are included in the ACE National Guide and for which you have earned an edX verified certificate. However, it is',
#  'in the ACE National Guide and for which you have earned an edX verified certificate. However, it is highly recommended that you check with your school in advance of taking our courses if you wish for them to be accepted for official academic credit. Free CS50 Certificates cannot be used to fulfill',
#  'them to be accepted for official academic credit. Free CS50 Certificates cannot be used to fulfill ACE’s requirements.\n\nThe process for obtaining such credit is as follows:\n\nSelect one of our courses from the ACE National Guide (see above).\nVerify with your academic institution whether or not they',
#  'from the ACE National Guide (see above).\nVerify with your academic institution whether or not they will accept this course, listed in the ACE National Guide, for academic credit.\nEnroll in the edX verified track for the course and make payment. You can do so utilizing one of the following',
#  'edX verified track for the course and make payment. You can do so utilizing one of the following links:\nCS50x\nCS50 AI\nCS50 Web\nEarn and receive your edX verified certificate for the course.\nObtain an official ACE credit note or ACE transcript from edX. Sometimes, the edX verified certificate alone',
#  'official ACE credit note or ACE transcript from edX. Sometimes, the edX verified certificate alone may be sufficient for ACE documentation, provided the verified certificate explicitly includes an ACE credit recommendation.\nClaim your ACE Credit Badge on Credly. edX will typically provide you with',
#  'credit recommendation.\nClaim your ACE Credit Badge on Credly. edX will typically provide you with a link or invitation to claim your Credly badge when they issue your edX verified certificate.\nRetain your edX verified certificate, your ACE documentation (such as credit note or transcript), and your',
#  'your edX verified certificate, your ACE documentation (such as credit note or transcript), and your Credly badge.\nWhen appropriate, present these forms of documentation of completion to your academic institution.\nIf you previously completed the course during the enrollment period listed on the ACE',
#  'institution.\nIf you previously completed the course during the enrollment period listed on the ACE National Guide website and obtain a verified certificate, you will be able to retroactively obtain the above. However, the course completion must have taken place during the enrollment period, which',
#  'the above. However, the course completion must have taken place during the enrollment period, which changes from time to time. If you wish to upgrade to an edX verified certificate after you have completed the course, after you have verified your enrollment period was during the period stated by',
#  'the course, after you have verified your enrollment period was during the period stated by the ACE National guide (see above), you can see our certificate upgrade instructions.\n\nAll inquiries about ACE credit should be directed to edX support.\n\nCan I obtain a letter confirming my enrollment and',
#  'ACE credit should be directed to edX support.\n\nCan I obtain a letter confirming my enrollment and details of the course?\nWe cannot provide a personalized email detailing your enrollment in this course. However, you are welcome to sign up for an edx verified certificate for the purpose of providing',
#  'However, you are welcome to sign up for an edx verified certificate for the purpose of providing proof that you are enrolled in the course. Further, you can obtain details about this course from the course page. Finally, concerning the time requirements for the course, you can add together the time',
#  'page. Finally, concerning the time requirements for the course, you can add together the time of each week’s course lectures yourself. For time required for the required assignments, best to estimate between 10-20 hours for each week’s problem sets.\n\nSigning Up\nHow do I sign up for the course?\nYou',
#  'between 10-20 hours for each week’s problem sets.\n\nSigning Up\nHow do I sign up for the course?\nYou can sign up by following the instructions on the course page.\n\nWhat’s the difference between a verified certificate and a CS50 Certificate?\nA verified certificate, which you can purchase from edX,',
#  'certificate and a CS50 Certificate?\nA verified certificate, which you can purchase from edX, “can provide proof for an employer, school, or other institution that you have successfully completed an online course.”\n\nA CS50 Certificate is a free certificate from CS50 itself.\n\nIf I sign up for a',
#  'an online course.”\n\nA CS50 Certificate is a free certificate from CS50 itself.\n\nIf I sign up for a verified certificate, can I also get a free certificate?\nYes.\n\nIs edX registration required?\nYes. Regardless of which certificate you are pursuing (free or verified), you must register with edX.\n\nedX',
#  'of which certificate you are pursuing (free or verified), you must register with edX.\n\nedX is requiring me to pay to register for the course: How do I get a free certificate?\nBest to carefully re-read edX’s questions on their website as you register. There is a “free” or “audit” option which',
#  're-read edX’s questions on their website as you register. There is a “free” or “audit” option which requires no payment.\n\nIf I want an edX verified certificate in the future, do I have to pay for verification before starting the course?\nNope! If you would like a verified certificate from edX, you',
#  'before starting the course?\nNope! If you would like a verified certificate from edX, you can pay for verification at any point up until 10 days before the course’s final deadline, even after completing all of the coursework. However, we strongly recommend, to avoid any logistical issues that can',
#  'all of the coursework. However, we strongly recommend, to avoid any logistical issues that can delay certificate issuance, that you verify before finishing the course. Otherwise, the 30-day wait we reference below only starts once you have had your identity verified by edX. Thus, waiting to',
#  'we reference below only starts once you have had your identity verified by edX. Thus, waiting to register for a verified certificate after you complete the course will likely delay receiving your verified certificate for 30 days or more.\n\nIf I paid for a verified certificate after I completed the',
#  'certificate for 30 days or more.\n\nIf I paid for a verified certificate after I completed the course, do I need to tell you?\nIf you completed the course during this calendar year: No. As long as your Gradebook shows that you have completed the course, you will receive your certificate up to 30 days',
#  'Gradebook shows that you have completed the course, you will receive your certificate up to 30 days after you make payment for a verified certificate with edX.\n\nIf you completed the course prior to this calendar year: Yes. Send us a copy of your CS50 Certificate, your edX and GitHub username that',
#  'this calendar year: Yes. Send us a copy of your CS50 Certificate, your edX and GitHub username that you used to complete the course, and a receipt from your purchase of the edX verified certificate. You must purchase the edX verified certificate using the same edX account you used to complete the',
#  'You must purchase the edX verified certificate using the same edX account you used to complete the course prior.\n\nCan I get a verified certificate for a CS50 course I completed prior to this year?\nYes, we can provide a verified certificate for any course completion from 2019 to present. We do so',
#  'we can provide a verified certificate for any course completion from 2019 to present. We do so provided that you can send us a copy of your CS50 Certificate, your edX and GitHub username that you used to complete the course, and a receipt from your purchase of the edX verified certificate. Without',
#  'to complete the course, and a receipt from your purchase of the edX verified certificate. Without this information, we cannot provide such a certificate.\n\nIf I paid for a verified certificate before this calendar year, do I need to pay again?\nNo, your verification should be good for an entire year,',
#  'calendar year, do I need to pay again?\nNo, your verification should be good for an entire year, but if it has expired, you should be able to re-verify yourself via edX’s dashboard.\n\nTracking Your Progress\nHow do I know if I have completed all requirements for a certificate?\nYour Gradebook shows the',
#  'do I know if I have completed all requirements for a certificate?\nYour Gradebook shows the result for each assignment submission for the most current version of the course. The top of your Gradebook shows your current status in the course, showing the number of required assignments you have',
#  'shows your current status in the course, showing the number of required assignments you have completed. If your Gradebook states that you are not enrolled in the course, best to enroll and start completing the required assignments.\n\nThis course requires multiple assignments to be submitted in some',
#  'the required assignments.\n\nThis course requires multiple assignments to be submitted in some weeks and only one assignment in other weeks. When you have completed requirements for a given week (as by receiving a score of 70% or higher on all required problems), the week number will be shown in',
#  'by receiving a score of 70% or higher on all required problems), the week number will be shown in green, and your progress indicator will be updated to reflect that.\n\nOnce you have scored at least a 70% on all required assignments, you will see a green banner atop that page, confirming your',
#  'a 70% on all required assignments, you will see a green banner atop that page, confirming your completion and providing you next steps to obtain your certificate(s).\n\nWhat / where is the Gradebook for this course?\nCS50x uses our own Gradebook. If you’ve never visited that link before, you’ll need',
#  'this course?\nCS50x uses our own Gradebook. If you’ve never visited that link before, you’ll need to click the link to “enroll,” which really just enables your Gradebook access! Registration with edX, whether for a free or verified certificate, is required.\n\nWhy does the Gradebook say that I am not',
#  'whether for a free or verified certificate, is required.\n\nWhy does the Gradebook say that I am not enrolled?\nThere are many potential reasons for this. The most common reasons are as follows. First, it’s possible that you never enrolled in the course before. Second, it’s possible that you never',
#  'it’s possible that you never enrolled in the course before. Second, it’s possible that you never linked your edX account to your gradebook. Best to follow the on-screen instructions in your Gradebook to resolve this issue and enroll.\n\nDoes this course have grades?\nNo. This course has numeric',
#  'to resolve this issue and enroll.\n\nDoes this course have grades?\nNo. This course has numeric scores. An assignment that receives a score of 70% or higher is considered passing.\n\nDoes my Gradebook only show if I scored high enough to pass a problem? How can I see my actual numeric grades?\nYour',
#  'only show if I scored high enough to pass a problem? How can I see my actual numeric grades?\nYour Gradebook will display a green check if you passed a submitted assignment and a red “x” if you did not pass a submitted assignment.\n\nYour overall problem score is weighted 75% for correctness and 25%',
#  'pass a submitted assignment.\n\nYour overall problem score is weighted 75% for correctness and 25% for style. In order to receive the green tick indicating completion, your overall score must be 70% or higher. As an example, if your check50 score is 7/8 and your style score is 0.95, your overall',
#  'or higher. As an example, if your check50 score is 7/8 and your style score is 0.95, your overall score will be (7/8 * 0.75) + (0.95 * 0.25) = 89%. You can click the problem name in your Gradebook to see your individual check50 and style50 scores.\n\nI completed an assignment or this course in a',
#  'to see your individual check50 and style50 scores.\n\nI completed an assignment or this course in a prior year. Why does my Gradebook no longer show my prior progress?\nAt the start of each calendar year, we clean up our Gradebook and “reset” it. What happened to your progress depends on when you last',
#  'we clean up our Gradebook and “reset” it. What happened to your progress depends on when you last submitted an assignment for the course.\n\nWhy does edX think my grade is 0%?\nThis course does not use edX’s built-in gradebook, so all students’ scores always appear (in edX’s gradebook) as 0%. Not to',
#  'edX’s built-in gradebook, so all students’ scores always appear (in edX’s gradebook) as 0%. Not to worry, see your Gradebook for your actual results. If you recently completed the course, it can take up to 30 days for edX to acknowledge your completion on your edX dashboard.\n\nI watched all the',
#  'take up to 30 days for edX to acknowledge your completion on your edX dashboard.\n\nI watched all the videos in edX or on YouTube: Why don’t I have a certificate?\nThis course has numerous assignments that must be completed in addition to watching the course lectures. Best to see the course menu,',
#  'that must be completed in addition to watching the course lectures. Best to see the course menu, which lists the various assignments for the course.\n\nWhy does my edX dashboard say I can “resume” the course even though I have completed it?\nYour edX dashboard may display either View Course or Resume',
#  'course even though I have completed it?\nYour edX dashboard may display either View Course or Resume Course as a convenience to you, such that you can return or view the course. It doesn’t indicate completion or non-completion.\n\nGitHub has disabled my account. What do I do?\nBest to consult GitHub’s',
#  'or non-completion.\n\nGitHub has disabled my account. What do I do?\nBest to consult GitHub’s documentation regarding account reinstatement. We cannot transfer your past progress to a new GitHub account. Further, we cannot access your files from a disabled GitHub account. If you cannot regain access',
#  'Further, we cannot access your files from a disabled GitHub account. If you cannot regain access to your GitHub account, you will need to restart the course.\n\nProblem Sets, Assignments, and Assessments\nDoes this course have a test?\nThis course does not have a summative test or “final exam.” While',
#  'this course have a test?\nThis course does not have a summative test or “final exam.” While our courses at Harvard College and Harvard Extension often have final tests, this course does not. You need only complete the assignments listed in each week or module of the course.\n\nWhat’s the difference',
#  'only complete the assignments listed in each week or module of the course.\n\nWhat’s the difference between “less comfortable” and “more comfortable” problems? Do I have to do both?\nIn some earlier problem sets, you’ll have a choice between a “less comfortable” and a “more comfortable” problem.\n\nThe',
#  'sets, you’ll have a choice between a “less comfortable” and a “more comfortable” problem.\n\nThe “less comfortable” problems are what you might consider the “standard” version of the problem, designed for students who have little or no prior experience. The “more comfortable” problems are the',
#  'for students who have little or no prior experience. The “more comfortable” problems are the “challenge” version, designed for students who consider themselves more comfortable due to prior study/experience before this class. As such, they may require more concepts than have been covered in the',
#  'before this class. As such, they may require more concepts than have been covered in the course so far.\n\nIf you find yourself really struggling with the “more comfortable” version, you should switch to the “less” version (or if you’ve already completed that, simply move on and perhaps revisit in a',
#  'to the “less” version (or if you’ve already completed that, simply move on and perhaps revisit in a later week). It would be better for you to skip the problem than to become so frustrated as to drop out of the course entirely. For reference, in the Fall 2019 Harvard class, only 20-30% of students',
#  'out of the course entirely. For reference, in the Fall 2019 Harvard class, only 20-30% of students submitted the “more comfortable” problems.\n\nYou don’t get any extra points for doing the “more comfortable” problems. If you submit both, the one with the highest grade will count towards your overall',
#  'problems. If you submit both, the one with the highest grade will count towards your overall course progress.\n\nDid you get my submission?\nOnce you execute the submit50 command with the appropriate slug as instructed by the assignment specification, your Gradebook will be immediately updated with',
#  'slug as instructed by the assignment specification, your Gradebook will be immediately updated with your passing status, provided that your submission was passing! Before using submit50, best to use check50 to make sure you have completed the entire problem before submission.\n\nI submitted a',
#  'to use check50 to make sure you have completed the entire problem before submission.\n\nI submitted a project, but nothing is showing up in my Gradebook yet showing that I’ve submitted. Why?\nProvided that you have executed the submit50 command with the appropriate slug as instructed by the assignment',
#  'you have executed the submit50 command with the appropriate slug as instructed by the assignment specification, your passing status should immediately be posted to your Gradebook. First, best to run check50 on your assignment to ensure it fulfills the requirements. Second, if that still does not',
#  'check50 on your assignment to ensure it fulfills the requirements. Second, if that still does not work, ensure that the GitHub username you are using to log into CS50.dev is the same GitHub username that appears at the top of your Gradebook.\n\nIf I submitted a problem and did not reach the 70%',
#  'that appears at the top of your Gradebook.\n\nIf I submitted a problem and did not reach the 70% passing grade, can I resubmit?\nYes! You may resubmit; we will only count your most recent submission towards your progress.\n\nIf my check50 score is not as expected, why might that be?\nYour check50 score',
#  'your progress.\n\nIf my check50 score is not as expected, why might that be?\nYour check50 score is accurate. After running check50, note that a URL will be provided linking you to your results. Note that check50 will look for precise fulfillment of the checks. Hence, if it is expecting a line break',
#  'check50 will look for precise fulfillment of the checks. Hence, if it is expecting a line break after an output and no such line break exists, the check will show as unfulfilled. In some cases, the expected and actual output may look exactly the same in the check50 results. In such an instance,',
#  'expected and actual output may look exactly the same in the check50 results. In such an instance, best to consider how spaces and other non-visible characters may be at play. Of course, it’s also possible that you have misunderstood a portion of the assignment and need to re-read the problem set',
#  'that you have misunderstood a portion of the assignment and need to re-read the problem set specification.\n\nIf my style score is not as expected, why might that be?\nYour style grade will be based on the style50 results for every source code file in your submission. When you run submit50, be sure',
#  'the style50 results for every source code file in your submission. When you run submit50, be sure that your folder includes only those files that are necessary for the problem set. If you have any extra test files in there, those will be counted towards your grade. Remove the extra files from the',
#  'test files in there, those will be counted towards your grade. Remove the extra files from the folder and resubmit to get an updated Style score.\n\nWhy did I not pass my final project?\nAfter submitting your final project, you can view your submission in your Gradebook to learn details about your',
#  'your final project, you can view your submission in your Gradebook to learn details about your score and why you did not pass.\n\nThe most common reason for not receiving a passing score on your final project is that you have not followed the Final Project Specification.\n\nThe second most common',
#  'project is that you have not followed the Final Project Specification.\n\nThe second most common reason for not receiving a passing score on your final project relates to your documentation (your final project’s README or DESIGN file). When your README or DESIGN documentation does not fulfill the',
#  'project’s README or DESIGN file). When your README or DESIGN documentation does not fulfill the stated requirements, you will not pass the final project. The documentation file should be quite robust. Students that don’t complete a robust documentation file, including MANY paragraphs will not',
#  'Students that don’t complete a robust documentation file, including MANY paragraphs will not receive a passing grade. You are highly advised to create a robust documentation file, including the precise sections mentioned by the Final Project Specification. Further, note that the Final Project',
#  'precise sections mentioned by the Final Project Specification. Further, note that the Final Project Specification includes a rough word count for your documentation. Following these specifications will ensure that your documentation file includes all the details required for you to be able to',
#  'will ensure that your documentation file includes all the details required for you to be able to pass.\n\nIf I did 70% of the problems, do I get a certificate?\nNo. You must do all the required assignments and receive at least a score of 70% on each.\n\nAm I cheating?\nBest to refer to our Academic',
#  'and receive at least a score of 70% on each.\n\nAm I cheating?\nBest to refer to our Academic Honesty policy to see.\n\nDeadlines\nWhen are the deadlines?\nThis course does not have individual deadlines for assignments. You are welcome to work on and submit at your own pace.\n\nThe overall deadline for the',
#  'assignments. You are welcome to work on and submit at your own pace.\n\nThe overall deadline for the course is currently end-of-day UTC, sometimes referred to as Zulu Time, on 31 December 2026 at 11:59PM. For your convenience, we will often render this time in your local timezone (Friday, January 1,',
#  'For your convenience, we will often render this time in your local timezone (Friday, January 1, 2027 at 5:44 AM GMT+5:45).\n\nIf all required work is turned in before the above time and ultimately receives a satisfactory grade (whether before or shortly after that deadline), you will be considered to',
#  'a satisfactory grade (whether before or shortly after that deadline), you will be considered to have completed the course.\n\nIf I don’t finish the course before end-of-day 31 December 2026, what will happen?\nShould the course be extended into another year, all work completed in 2026 will be carried',
#  'happen?\nShould the course be extended into another year, all work completed in 2026 will be carried forward into 2027. If the course is updated for 2027, after 2026, you may only submit the 2027 version’s problem sets and will need to satisfy whatever requirements are in the course at that time.',
#  'problem sets and will need to satisfy whatever requirements are in the course at that time. Work submitted in 2025 and prior will not carry into 2027.\n\nIf I started CS50x before this calendar year, can I resume?\nYes, any completed1 problems in 2025 have been carried forward to your CS50x 2026',
#  'can I resume?\nYes, any completed1 problems in 2025 have been carried forward to your CS50x 2026 gradebook. You’ll see completed problems marked with green checkmarks. Moving forward, you must submit CS50x 2026’s problem sets. Work from prior versions of the course may not be submitted for credit.',
#  'CS50x 2026’s problem sets. Work from prior versions of the course may not be submitted for credit. Work submitted before to 2025 does not count toward your progress in 2026.\n\n1 By completed, we mean you earned a score of 70% or better on the problem before the prior deadline.\n\nObtaining Your',
#  'mean you earned a score of 70% or better on the problem before the prior deadline.\n\nObtaining Your Certificate\nHow do I get my free CS50 Certificate?\nOnce you have completed the course and met all of the requirements (per the above), you’ll see a link on your Gradebook page allowing you to request',
#  'the requirements (per the above), you’ll see a link on your Gradebook page allowing you to request a free CS50 Certificate, much like the one shown here. This link will be available within approximately four hours after you receive your score for your last required assignment and your progress bar',
#  'four hours after you receive your score for your last required assignment and your progress bar in your Gradebook indicates course completion. Once this link appears, you should then proceed to log in using your GitHub credentials. If you have trouble accessing it, try logging out of GitHub and',
#  'in using your GitHub credentials. If you have trouble accessing it, try logging out of GitHub and back in, then revisit the link to download your certificate. Be sure to download your free certificate before the deadline.\n\nHow do I get my verified certificate from edX?\nEvery three weeks, CS50’s',
#  'before the deadline.\n\nHow do I get my verified certificate from edX?\nEvery three weeks, CS50’s staff provides edX with a list of students who have satisfied the course’s requirements (by receiving scores of at least 70% on each of all of the required problems). Typically, within a week thereafter,',
#  'of at least 70% on each of all of the required problems). Typically, within a week thereafter, edX then generates students’ verified certificates (for students who have active verification), at which point they should appear automatically on edX’s dashboard. Thus, after you have satisfied the',
#  'which point they should appear automatically on edX’s dashboard. Thus, after you have satisfied the course’s requirements, it can take up to 30 days for your verified certificate to be generated by edX. Note that edX will not notify you, so be sure to check your dashboard periodically.\n\nIf it has',
#  'edX. Note that edX will not notify you, so be sure to check your dashboard periodically.\n\nIf it has been more than 30 days since you met all requirements and you have still not received your certificate despite holding an active Verification that whole time, email certificates@cs50.harvard.edu with',
#  'despite holding an active Verification that whole time, email certificates@cs50.harvard.edu with your details. Please do not email sooner; we cannot accept requests for expedited processing of verified certificates.\n\nCan you rush the issuance of my verified certificate from edX?\nNo.\n\nWhy did I not',
#  'certificates.\n\nCan you rush the issuance of my verified certificate from edX?\nNo.\n\nWhy did I not get my verified certificate after 30 days?\nFirst, recall that your verified edX certificate will be issued by edX up to 30 days after three criteria are met: (a) Your Gradebook shows that you have',
#  'be issued by edX up to 30 days after three criteria are met: (a) Your Gradebook shows that you have completed all of the required assignments with at least a 70% score or higher on each, (b) you have made payment to edX and completed their verification process, resulting in a verified badge on your',
#  'made payment to edX and completed their verification process, resulting in a verified badge on your edX dashboard, and (c) you have linked your Gradebook to your edX account. Thus, you should ensure that 30 days have passed since all three of these above criteria have occurred.\n\nSecond, we can only',
#  '30 days have passed since all three of these above criteria have occurred.\n\nSecond, we can only inform edX of your passing status if you have linked your Gradebook to edX. Visit your Gradebook and ensure that no gold bar appears at the top of the page stating that you must link your Gradebook to',
#  'ensure that no gold bar appears at the top of the page stating that you must link your Gradebook to your edX account. If you see such a gold bar, complete the linking process. Then, re-read the above about the timing in which you might expect to receive your certificate.\n\nFinally, if you still have',
#  'about the timing in which you might expect to receive your certificate.\n\nFinally, if you still have not received your edX certificate, best to ensure that the edX username that appears at the top of your Gradebook is the same edX username that appears at the top of your edX dashboard. If there is a',
#  'Gradebook is the same edX username that appears at the top of your edX dashboard. If there is a mismatch between these usernames, you will need to inform edX that they need to transfer your verification payment to the correct username, as we have likely already informed them that the edX username',
#  'payment to the correct username, as we have likely already informed them that the edX username that appears on top of your Gradebook has passed the course.\n\nWhat name will appear on my certificate?\nFree certificates will include the name you provide when you claim your certificate. You will',
#  'certificates will include the name you provide when you claim your certificate. You will personally type the name you wish to appear on your certificate during the redemption process. Make sure you type the name you desire to appear on your certificate!\n\nVerified certificates provided through edX',
#  'type the name you desire to appear on your certificate!\n\nVerified certificates provided through edX will include the name associated with your edX account.\n\nCan I change the name on my certificate?\nNo, we cannot make changes to the name on your certificate. Because we rely upon you to type the name',
#  'we cannot make changes to the name on your certificate. Because we rely upon you to type the name correctly and because of the huge number of students with whom we work, it is not feasible for us to provide name changes. You are welcome to upgrade to a verified certificate and communicate with edX',
#  'provide name changes. You are welcome to upgrade to a verified certificate and communicate with edX about what name will appear on your verified edX certificate by emailing them at info@edX.org.\n\nDo you offer a printed certificate?\nNo. Best to take your digital certificate to a local print shop',
#  'you offer a printed certificate?\nNo. Best to take your digital certificate to a local print shop that will print it for you.\n\nUsing Your Certificate\nHow should I describe my verified certificate on my resume or elsewhere?\nWhen citing your HarvardX credentials on your resume or LinkedIn profile',
#  'on my resume or elsewhere?\nWhen citing your HarvardX credentials on your resume or LinkedIn profile relating to your verified edX certificate, please utilize this template:\n\nFor your resume, use the following language: HarvardX [Course name]\n\nFor listing your certificate on your LinkedIn profile,',
#  'following language: HarvardX [Course name]\n\nFor listing your certificate on your LinkedIn profile, input details under the “Education” as follows: School: HarvardX Dates Attended: [The year you participated in the program] Degree: Other; Certificate in [Course name] Field of Study: Leave blank',
#  'in the program] Degree: Other; Certificate in [Course name] Field of Study: Leave blank Grade: Complete Activities and Societies: Leave blank\n\nAdditionally, edX provides the following blog posts that may also be helpful:\n\n3 Reasons to Add Online Courses to Your CV and How To Do It. Specifically, at',
#  'may also be helpful:\n\n3 Reasons to Add Online Courses to Your CV and How To Do It. Specifically, at the end of the article, it discusses how you should add this information to your resume.\nHow can I add my certificate to my LinkedIn profile?\nSoftware and Hardware\nMy codespace is behaving strangely.',
#  'my certificate to my LinkedIn profile?\nSoftware and Hardware\nMy codespace is behaving strangely. What should I do?\nThe first step is always to attempt to restart your Codespace container. Issues can appear for a variety of reasons, but a restart, as by visiting cs50.dev/restart usually resolves the',
#  'for a variety of reasons, but a restart, as by visiting cs50.dev/restart usually resolves the problem. Do be very patient as it rebuilds and restarts, as this can take several minutes.\n\nIf this does not resolve the issue, best to refer to our technical documentation for Visual Studio Code for',
#  'does not resolve the issue, best to refer to our technical documentation for Visual Studio Code for CS50.\n\nWhy does it seem like content or third-party services related to this course seem blocked?\nYour computer, network, or local government may be blocking your ability to access our content or a',
#  'computer, network, or local government may be blocking your ability to access our content or a third-party tool related to this course. First, attempt to utilize another device connected to an alternative network to see if your device may be blocking your access. Consider virus scanners, firewalls,',
#  'network to see if your device may be blocking your access. Consider virus scanners, firewalls, and other security-related tools and software that may be blocking your access.\n\nSecond, consider the network on which you are attempting to access these resources may be blocking you. You may have to',
#  'network on which you are attempting to access these resources may be blocking you. You may have to speak to your network administrator or, at the least, attempt to seek out another network connection that allows you access.\n\nFinally, it’s possible that your local government is blocking access due',
#  'that allows you access.\n\nFinally, it’s possible that your local government is blocking access due to trade- or content-related laws.\n\nIn all of the cases above, best to reach out to one of our many communities for help.\n\nCan you help me circumvent content blocking that is preventing me from',
#  'many communities for help.\n\nCan you help me circumvent content blocking that is preventing me from accessing your course and its associated third-party services?\nNo.\n\nCan I change my GitHub or edX username while taking the course?\nNo. Changing your GitHub or edX username will result in you losing',
#  'while taking the course?\nNo. Changing your GitHub or edX username will result in you losing your course progress. Once lost, we will not be able to retrieve it for you. If you have already changed one of your usernames, best to change it back.\n\nSupport\nDoes this course have office hours?\nNot',
#  'one of your usernames, best to change it back.\n\nSupport\nDoes this course have office hours?\nNot regularly! But you can still ask questions in any of CS50’s communities! Additionally, check to see what upcoming meetings are being held in the near future.\n\nDoes this course have sections?\nYes! While',
#  'upcoming meetings are being held in the near future.\n\nDoes this course have sections?\nYes! While the course is too large to hold live sections for current students, pre-recorded sections are available here for students to supplement the other course materials. Additionally, check to see what',
#  'here for students to supplement the other course materials. Additionally, check to see what upcoming meetings are being held in the near future.\n\nCan you help me with my code?\nFor help on problem sets or course concepts, we ask that you reach out to one of our many communities. If you are not',
#  'sets or course concepts, we ask that you reach out to one of our many communities. If you are not already a user of any of those communities listed at the link above, allow us to suggest that you start with CS50.ai and Ed!\n\nBeyond This Course\nWhich course should I take?\nWe offer many courses. For',
#  'with CS50.ai and Ed!\n\nBeyond This Course\nWhich course should I take?\nWe offer many courses. For each, we offer verified certificates for a fee and a free certificate. Verified certificates involve a verification process through edX and, therefore, may be regarded by others as more authentic. Free',
#  'verification process through edX and, therefore, may be regarded by others as more authentic. Free certificates are issued using a unique URL. Some of our courses are geared toward those who want to learn more about programming and data science. Some of our courses are geared toward professionals',
#  'learn more about programming and data science. Some of our courses are geared toward professionals who do not want to jump into programming right away.\n\nCan I teach this course to my students?\nIf you are a teacher, you are welcome to adopt or adapt these materials for your own course, per the',
#  'you are a teacher, you are welcome to adopt or adapt these materials for your own course, per the license. Also, check out the CS50 Educator Workshop.\n\nAcademic Honesty\nThis course’s philosophy on academic honesty is best stated as “be reasonable.” The course recognizes that interactions with',
#  'on academic honesty is best stated as “be reasonable.” The course recognizes that interactions with classmates and others can facilitate mastery of the course’s material. However, there remains a line between enlisting the help of another and submitting the work of another. The course’s policy',
#  'line between enlisting the help of another and submitting the work of another. The course’s policy characterizes both sides of that line.\n\nWatch this video for context\nOr read this paper for context.\n\nPolicy\nThe essence of all work that you submit to this course must be your own. Unless otherwise',
#  'essence of all work that you submit to this course must be your own. Unless otherwise specified, collaboration on assessments (e.g., assignments, labs, problem sets, projects, quizzes, or tests) is not permitted except to the extent that you may ask classmates and others for help so long as that',
#  'not permitted except to the extent that you may ask classmates and others for help so long as that help does not reduce to another doing your work for you. Generally speaking, when asking for help, you may show your work to others, but you may not view theirs, so long as you and they respect this',
#  'you may show your work to others, but you may not view theirs, so long as you and they respect this policy’s other constraints.\n\nRegret clause. If you commit some act that is not reasonable but bring it to the attention of the course’s heads by emailing certificates@cs50.harvard.edu within 72',
#  'bring it to the attention of the course’s heads by emailing certificates@cs50.harvard.edu within 72 hours, the course may impose local sanctions that may include an unsatisfactory or failing grade for work submitted, but the course will not refer the matter for further disciplinary action except in',
#  'work submitted, but the course will not refer the matter for further disciplinary action except in cases of repeated acts.\n\nBelow are rules of thumb that (inexhaustively) characterize acts that the course considers reasonable and not reasonable. If in doubt as to whether some act is reasonable, do',
#  'considers reasonable and not reasonable. If in doubt as to whether some act is reasonable, do not commit it until you solicit and receive approval in writing from the course’s heads. Acts considered not reasonable by the course are handled harshly. If the course refers some matter for disciplinary',
#  'not reasonable by the course are handled harshly. If the course refers some matter for disciplinary action and the outcome is punitive, the course reserves the right to impose local sanctions on top of that outcome that may include an unsatisfactory or failing grade for work submitted or for the',
#  'of that outcome that may include an unsatisfactory or failing grade for work submitted or for the course itself. The course ordinarily recommends exclusion (i.e., required withdrawal) from the course itself.\n\nReasonable\nCommunicating with classmates about assessments in English (or some other',
#  'itself.\n\nReasonable\nCommunicating with classmates about assessments in English (or some other spoken language), and properly citing those discussions.\nDiscussing the course’s material with others in order to understand it better.\nHelping a classmate identify a bug in their code, as by viewing,',
#  'in order to understand it better.\nHelping a classmate identify a bug in their code, as by viewing, compiling, or running their code after you have submitted that portion of the pset yourself.\nIncorporating a few lines of code that you find online or elsewhere into your own code, provided that those',
#  'a few lines of code that you find online or elsewhere into your own code, provided that those lines are not themselves solutions to assigned work and that you cite the lines’ origins.\nSending or showing code that you’ve written to someone, possibly a classmate, so that they might help you identify',
#  'code that you’ve written to someone, possibly a classmate, so that they might help you identify and fix a bug.\nSubmitting the same or similar work to this course that you have submitted previously to this course.\nTurning to the web or elsewhere for instruction beyond the course’s own, for',
#  'to this course.\nTurning to the web or elsewhere for instruction beyond the course’s own, for references, and for solutions to technical difficulties, but not for outright solutions to assigned work.\nUsing CS50’s own AI-based software, including the CS50 Duck (ddb) in cs50.ai and',
#  'to assigned work.\nUsing CS50’s own AI-based software, including the CS50 Duck (ddb) in cs50.ai and cs50.dev.\nWhiteboarding solutions with others using diagrams or pseudocode but not actual code.\nWorking with (and even paying) a tutor to help you with the course, provided the tutor does not do your',
#  'with (and even paying) a tutor to help you with the course, provided the tutor does not do your work for you.\nNot Reasonable\nAccessing a solution to some assessement prior to (re-)submitting your own.\nAccessing or attempting to access, without permission, an account not your own.\nAsking a classmate',
#  'or attempting to access, without permission, an account not your own.\nAsking a classmate to see their solution to some assessment before (re-)submitting your own.\nDiscovering but failing to disclose to the course’s heads bugs in the course’s software that affect scores.\nDecompiling, deobfuscating,',
#  'to the course’s heads bugs in the course’s software that affect scores.\nDecompiling, deobfuscating, or disassembling the staff’s solutions.\nFailing to cite (as with comments) the origins of code or techniques that you discover outside of the course’s own lessons and integrate into your own work,',
#  'techniques that you discover outside of the course’s own lessons and integrate into your own work, even while respecting this policy’s other constraints.\nGiving or showing to a classmate a solution to an assessment when it is they, and not you, who is struggling to solve it.\nManipulating or',
#  'to an assessment when it is they, and not you, who is struggling to solve it.\nManipulating or attempting to manipulate scores artificially, as by exploiting bugs or formulas in the course’s software.\nPaying or offering to pay an individual for work that you may submit as (part of) your',
#  'software.\nPaying or offering to pay an individual for work that you may submit as (part of) your own.\nProviding or making available solutions to assessments to anyone, whether a past, present, or prospective future student.\nSearching for or soliciting outright solutions to assessments online or',
#  'prospective future student.\nSearching for or soliciting outright solutions to assessments online or elsewhere.\nSplitting an assessment’s workload with another individual and combining your work.\nSubmitting (after possibly modifying) the work of another individual beyond the few lines allowed',
#  '(after possibly modifying) the work of another individual beyond the few lines allowed herein.\nSubmitting the same or similar work to this course that you have submitted or will submit to another course, unless explictly allowed.\nUsing AI-based software other than CS50’s own (e.g., ChatGPT, Claude,',
#  'unless explictly allowed.\nUsing AI-based software other than CS50’s own (e.g., ChatGPT, Claude, Copilot, Gemini, et al.) that suggests or completes answers to questions or lines of code.\nViewing another’s solution to an assessment and basing your own solution on it.']

# %%
# hybrid search

# %%
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

# %%
from langchain_community.retrievers import BM25Retriever
from langchain_classic.retrievers import EnsembleRetriever

# %%
vector_retriever = vectore_store.as_retriever(search_kwargs={"k":1})
bm_retriever = BM25Retriever.from_documents(documents)
bm_retriever.k = 1

# %%
retriever = EnsembleRetriever(retrievers=[vector_retriever,bm_retriever],weights=[0.3,0.7])

# %%
retriever.invoke("can i take this course?")
# Out:
# [Document(metadata={}, page_content='Should I Take This Course?\nAm I or my child too young to take this course?\nOur courses are perhaps best suited for learners ages 12 and up. Younger learners might need a hand from a parent. Please note that your local laws and policies may prevent learners under certain ages from utilizing free'),
#  Document(id='82f896a5-2c13-4aec-a0b4-a3e836290b7c', metadata={}, page_content='examine our course map to determine if this class is the right one for you at this point in your development as a learner.\n\nCan this course be used to fulfill official academic requirements for my university, college, or school?\nOur free and verified certificates are not accredited academic')]

# %%
from langsmith import
